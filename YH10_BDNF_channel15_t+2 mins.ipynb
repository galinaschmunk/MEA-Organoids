# %%
import neuraltoolkit as ntk
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib notebook

# %%
rawfile = '/Users/gal4en/Desktop/20190322.YH10/20190322_YH10_4_190322_174151.rhd'

# %%
rawfile
# Out:
# '/Users/gal4en/Desktop/20190322.YH10/20190322_YH10_4_190322_174151.rhd'

# %%
# Get number of channels
print("Enter total number of channels : ")
number_of_channels = np.int16(eval(input()))
# Out:
# Enter total number of channels :
# 32

# %%
# Time and data
t, dgc = ntk.load_intan_raw_gain_chanmap(rawfile, number_of_channels, 'linear')
# Out:
# Reading Intan Technologies RHD2000 Data File, Version 1.5
#
# n signal groups 7
# Found 32 amplifier channels.
# Found 3 auxiliary input channels.
# Found 1 supply voltage channel.
# Found 0 board ADC channels.
# Found 0 board digital input channels.
# Found 0 board digital output channels.
# Found 0 temperature sensors channels.
#
# File contains 42.806 seconds of data.  Amplifiers were sampled at 25.00 kS/s.
#
# Allocating memory for data...
# Reading data from file...
# 10% done...
# 20% done...
# 30% done...
# 40% done...
# 50% done...
# 60% done...
# 70% done...
# 80% done...
# 90% done...
# Parsing data...
# No missing timestamps in data.
# Done!  Elapsed time: 4.4 seconds
# linear

# %%
# bandpass filter
bdgc = ntk.butter_bandpass(dgc, 500, 7500, 25000, 3)

# %%
#help (ntk.butter_bandpass)
# Out:
# Help on function butter_bandpass in module neuraltoolkit.ntk_filters:
#
# butter_bandpass(data, highpass, lowpass, fs, order=3)
#     Butterworth bandpass filter
#     butter_bandpass(data, highpass, lowpass, fs, order=3)
#     result = butter_bandpass(data, 500, 4000, 25000, 3)

# %%
# plot data in channel list
l = np.array([14])
ntk.plot_data_chlist(bdgc, 25000, 50000*46, l )
# Out:
# 0   14
# <img src="data:image/png;base64,..." width="640">

# %%
# plot raw data
ntk.plot_data(dgc, 0, 25000*120, 14)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# plot bandpassed data
ntk.plot_data(bdgc, 0, 25000*120, 14)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# plot bandpassed data
ntk.plot_data(bdgc, 0, 25000*46, 14)
# Out:
# <img src="data:image/png;base64,..." width="640">
